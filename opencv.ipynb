# %% [markdown]
# # OpenCV

# %%
import time
import os
import pandas as pd
import numpy as np
import cv2
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#im = cv2.imread('lenna.png')

# %%
#im.shape

# %% [markdown]
# カラー画像のデータ構造

# %% [markdown]
# ![image.png](attachment:92456e86-ee67-4b30-8b1f-61feb3ab4d47.png)

# %%
# plt.imshow(im)  #歴史的理由からRGBではなBGRになっている

# %%
#rgb = cv2.cvtColor(im, cv2.COLOR_BGR2RGB)
# rgb = cv2.cvtColor(im, 4) 同じ結果になる
#plt.imshow(rgb)

# %%
momo = cv2.imread('momona_ofuro.jfif')
momo = cv2.cvtColor(momo, 4)
# plt.imshow(momo)

# %%
gray = cv2.cvtColor(momo, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='gray')

# %%
#高さ：上500pxと下1500px　横：左右両方500px切り取る
# crop = momo[500:-1500, 500:-500, :]
# plt.imshow(crop)

# %%
# cv2.imwrite('cropped_momo.png', crop)

# %%
crop_momo = cv2.imread('cropped_momo.png')
plt.imshow(crop_momo)

# %% [markdown]
# # 2値化

# %%
# plt.imshow(gray, cmap='gray')

# %%
retval, dist = cv2.threshold(gray, 90, 255, cv2.THRESH_BINARY)
plt.imshow(dist, cmap='gray')
plt.axis('off')
plt.show()

# %% [markdown]
# # 大津の2値化

# %%
im = cv2.imread('bimodal_sample.png')
# plt.imshow(im)

# %%
im.shape

# %%
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
# plt.imshow(gray, cmap='gray')

# %%
gray.shape

# %%
# sns.displot(gray.ravel(), bins=256, kde=True)

# %%
retval, dist = cv2.threshold(gray, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)

# %%
print(f"2値化される場所は {retval}")

# %%
plt.imshow(dist,cmap='gray')

# %%
momo = cv2.imread('momona_ofuro.jfif')
momo = momo[500:-1500, 500:-500, :]
momo = cv2.cvtColor(momo, cv2.COLOR_BGR2GRAY)
retval, dist = cv2.threshold(momo, 0, 255, cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.imshow(dist,cmap='gray')
plt.axis('off')
plt.show()
cv2.imwrite('binary_momo.png', momo)

# %% [markdown]
# # Adaptive Thresholding

# %%
im = plt.imread('text_pic.jpg')
plt.imshow(im)

# %%
gray = cv2.cvtColor(im, cv2.COLOR_BGR2GRAY)
# plt.imshow(gray, cmap='gray')
dist = cv2.adaptiveThreshold(gray, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, 15, 4)
plt.imshow(dist, cmap='gray')

# %%
coai = plt.imread('coai.jfif')
coai = cv2.cvtColor(coai, cv2.COLOR_BGR2GRAY)
dist = cv2.adaptiveThreshold(coai, 255, cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY, 25, 4)
plt.imshow(dist, cmap='gray')
plt.axis('off')
plt.show()
cv2.imwrite('binary_coai.png', coai)
